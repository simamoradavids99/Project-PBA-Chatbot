# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to C:\Users\ITD-
# [nltk_data]     STU\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\ITD-
# [nltk_data]     STU\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
intents
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi', 'How are you', 'Is anyone there?', 'Hello', 'Good day'],
#    'responses': ['Hello, thanks for visiting',
#     'Good to see you again',
#     'Hi there, how can I help?'],
#    'context_set': ''},
#   {'tag': 'goodbye',
#    'patterns': ['Bye', 'See you later', 'Goodbye'],
#    'responses': ['See you later, thanks for visiting',
#     'Have a nice day',
#     'Bye! Come back again soon.']},
#   {'tag': 'thanks',
#    'patterns': ['Thanks', 'Thank you', "That's helpful"],
#    'responses': ['Happy to help!', 'Any time!', 'My pleasure']},
#   {'tag': 'hours',
#    'patterns': ['What hours are you open?',
#     'What are your hours?',
#     'When are you open?'],
#    'responses': ["We're open every day 9am-9pm",
#     'Our hours are 9am-9pm every day']},
#   {'tag': 'mopeds',
#    'patterns': ['Which mopeds do you have?',
#     'What kinds of mopeds are there?',
#     'What do you rent?'],
#    'responses': ['We rent Yamaha, Piaggio and Vespa mopeds',
#     'We have Piaggio, Vespa and Yamaha mopeds']},
#   {'tag': 'payments',
#    'patterns': ['Do you take credit cards?',
#     'Do you accept Mastercard?',
#     'Are you cash only?'],
#    'responses': ['We accept VISA, Mastercard and AMEX',
#     'We accept most major credit cards']},
#   {'tag': 'opentoday',
#    'patterns': ['Are you open today?',
#     'When do you open today?',
#     'What are your hours today?'],
#    'responses': ["We're open every day from 9am-9pm",
#     'Our hours are 9am-9pm every day']},
#   {'tag': 'rental',
#    'patterns': ['Can we rent a moped?',
#     "I'd like to rent a moped",
#     'How does this work?'],
#    'responses': ['Are you looking to rent today or later this week?'],
#    'context_set': 'rentalday'},
#   {'tag': 'today',
#    'patterns': ['today'],
#    'responses': ['For rentals today please call 1-800-MYMOPED',
#     'Same-day rentals please call 1-800-MYMOPED'],
#    'context_filter': 'rentalday'}]}

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 27 documents
# 9 classes ['goodbye', 'greeting', 'hours', 'mopeds', 'opentoday', 'payments', 'rental', 'thanks', 'today']
# 49 unique lemmatized words ["'d", "'s", 'a', 'accept', 'anyone', 'are', 'bye', 'can', 'card', 'cash', 'credit', 'day', 'do', 'doe', 'good', 'goodbye', 'have', 'hello', 'helpful', 'hi', 'hour', 'how', 'i', 'is', 'kind', 'later', 'like', 'mastercard', 'moped', 'of', 'only', 'open', 'rent', 'see', 'take', 'thank', 'thanks', 'that', 'there', 'this', 'to', 'today', 'we', 'what', 'when', 'which', 'work', 'you', 'your']

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# C:\Users\ITD-STU\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3509 - accuracy: 0.9341
# Epoch 39/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4109 - accuracy: 0.8266
# Epoch 40/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2678 - accuracy: 0.9072
# Epoch 41/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6278 - accuracy: 0.8134
# Epoch 42/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4711 - accuracy: 0.8729
# Epoch 43/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3283 - accuracy: 0.9837
# Epoch 44/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2268 - accuracy: 0.9837
# Epoch 45/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6542 - accuracy: 0.8154
# Epoch 46/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3488 - accuracy: 0.9766
# Epoch 47/200
# 6/6 [==============================] - ETA: 0s - loss: 0.3073 - accuracy: 0.80 - 0s 3ms/step - loss: 0.2368 - accuracy: 0.9242
# Epoch 48/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4582 - accuracy: 0.8606
# Epoch 49/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4408 - accuracy: 0.8912
# Epoch 50/200
# 6/6 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 1.00 - 0s 2ms/step - loss: 0.1466 - accuracy: 1.0000
# Epoch 51/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1730 - accuracy: 1.0000
# Epoch 52/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1753 - accuracy: 0.9837
# Epoch 53/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2330 - accuracy: 0.9059
# Epoch 54/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2577 - accuracy: 0.9670
# Epoch 55/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1449 - accuracy: 0.9365
# Epoch 56/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2077 - accuracy: 0.9837
# Epoch 57/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4917 - accuracy: 0.8171
# Epoch 58/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3339 - accuracy: 0.9528
# Epoch 59/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1381 - accuracy: 1.0000
# Epoch 60/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2225 - accuracy: 1.0000
# Epoch 61/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3993 - accuracy: 0.9242
# Epoch 62/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1155 - accuracy: 1.0000
# Epoch 63/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1486 - accuracy: 1.0000
# Epoch 64/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4025 - accuracy: 0.8484
# Epoch 65/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1880 - accuracy: 0.9528
# Epoch 66/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2639 - accuracy: 0.8606
# Epoch 67/200
# 6/6 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 1.00 - 0s 3ms/step - loss: 0.3069 - accuracy: 0.9528
# Epoch 68/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1357 - accuracy: 0.9837
# Epoch 69/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2365 - accuracy: 0.8892
# Epoch 70/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1648 - accuracy: 0.9766
# Epoch 71/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 1.0000
# Epoch 72/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1545 - accuracy: 0.9766
# Epoch 73/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2463 - accuracy: 0.9242
# Epoch 74/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1058 - accuracy: 0.9837
# Epoch 75/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1914 - accuracy: 0.9766
# Epoch 76/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1576 - accuracy: 0.9603
# Epoch 77/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2950 - accuracy: 0.8773
# Epoch 78/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1615 - accuracy: 0.9766
# Epoch 79/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0610 - accuracy: 1.0000
# Epoch 80/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1134 - accuracy: 0.9670
# Epoch 81/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1415 - accuracy: 1.0000
# Epoch 82/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1003 - accuracy: 0.9670
# Epoch 83/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0940 - accuracy: 1.0000
# Epoch 84/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0600 - accuracy: 1.0000
# Epoch 85/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0802 - accuracy: 0.9837
# Epoch 86/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1960 - accuracy: 0.9670
# Epoch 87/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.3722 - accuracy: 0.8769
# Epoch 88/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 89/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1847 - accuracy: 0.9670
# Epoch 90/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2098 - accuracy: 0.9293
# Epoch 91/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1552 - accuracy: 0.9528
# Epoch 92/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0798 - accuracy: 0.9766
# Epoch 93/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 1.0000
# Epoch 94/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0822 - accuracy: 0.9766
# Epoch 95/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0747 - accuracy: 1.0000
# Epoch 96/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 97/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1777 - accuracy: 0.9436
# Epoch 98/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1093 - accuracy: 1.0000
# Epoch 99/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1151 - accuracy: 0.9766
# Epoch 100/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1281 - accuracy: 0.9837
# Epoch 101/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1879 - accuracy: 0.9007
# Epoch 102/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 103/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1633 - accuracy: 1.0000
# Epoch 104/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0742 - accuracy: 1.0000
# Epoch 105/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0803 - accuracy: 1.0000
# Epoch 106/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 107/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 0.9766
# Epoch 108/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0836 - accuracy: 1.0000
# Epoch 109/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0585 - accuracy: 0.9788
# Epoch 110/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1805 - accuracy: 0.9565
# Epoch 111/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1856 - accuracy: 0.9262
# Epoch 112/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 1.0000
# Epoch 113/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0429 - accuracy: 1.0000
# Epoch 114/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1433 - accuracy: 0.9293
# Epoch 115/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 116/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 117/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0909 - accuracy: 0.9670
# Epoch 118/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 1.0000
# Epoch 119/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0475 - accuracy: 1.0000
# Epoch 120/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1443 - accuracy: 0.9894
# Epoch 121/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9436
# Epoch 122/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 123/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1105 - accuracy: 0.9242
# Epoch 124/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1037 - accuracy: 0.9670
# Epoch 125/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0700 - accuracy: 1.0000
# Epoch 126/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 127/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 128/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 1.0000
# Epoch 129/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 130/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 131/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 132/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 133/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2537 - accuracy: 0.9242
# Epoch 134/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 1.0000
# Epoch 135/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0697 - accuracy: 0.9837
# Epoch 136/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0577 - accuracy: 0.9766
# Epoch 137/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1388 - accuracy: 0.9242
# Epoch 138/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 139/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 140/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 141/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0802 - accuracy: 0.9528
# Epoch 142/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 143/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0632 - accuracy: 1.0000
# Epoch 144/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 145/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1104 - accuracy: 0.9242
# Epoch 146/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0751 - accuracy: 1.0000
# Epoch 147/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0588 - accuracy: 1.0000
# Epoch 148/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1373 - accuracy: 0.9055
# Epoch 149/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0936 - accuracy: 0.9528
# Epoch 150/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 151/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 0.9837
# Epoch 152/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 0.9837
# Epoch 153/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 154/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 155/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 156/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2291 - accuracy: 0.9528
# Epoch 157/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 158/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0484 - accuracy: 1.0000
# Epoch 159/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 160/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 161/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0770 - accuracy: 1.0000
# Epoch 162/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0949 - accuracy: 1.0000
# Epoch 163/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 164/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0913 - accuracy: 0.9436
# Epoch 165/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 1.0000
# Epoch 166/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0486 - accuracy: 1.0000
# Epoch 167/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 1.0000
# Epoch 168/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 169/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1108 - accuracy: 0.9528
# Epoch 170/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1215 - accuracy: 1.0000
# Epoch 171/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1094 - accuracy: 1.0000
# Epoch 172/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 173/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0505 - accuracy: 1.0000
# Epoch 174/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 175/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9242
# Epoch 176/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0975 - accuracy: 0.9528
# Epoch 177/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 178/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0841 - accuracy: 0.9670
# Epoch 179/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0785 - accuracy: 0.9837
# Epoch 180/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1031 - accuracy: 0.9242
# Epoch 181/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2366 - accuracy: 0.8769
# Epoch 182/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9837
# Epoch 183/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0577 - accuracy: 0.9766
# Epoch 184/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 185/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1101 - accuracy: 0.9670
# Epoch 186/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 187/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 188/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 189/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0873 - accuracy: 1.0000
# Epoch 190/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 191/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 192/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 193/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0665 - accuracy: 1.0000
# Epoch 194/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0480 - accuracy: 0.9670
# Epoch 195/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 196/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1938 - accuracy: 0.9242
# Epoch 197/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.2397 - accuracy: 0.9528
# Epoch 198/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 199/200
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 1.0000
# Epoch 200/200
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 1.0000
# model created

# %%
from tensorflow.keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %%
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)


base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
